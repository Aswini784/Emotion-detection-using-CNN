# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout,BatchNormalization

# %%
data="/content/drive/MyDrive/data/DATASET/"

# %%
train_dg=ImageDataGenerator(rescale=1./255)
test_dg=ImageDataGenerator(rescale=1./255)

# %%
train_generator=train_dg.flow_from_directory(data+'train/',target_size=(48, 48),batch_size=32,color_mode='grayscale',class_mode='categorical')
# Out:
# Found 12404 images belonging to 7 classes.

# %%
test_generator=test_dg.flow_from_directory(data+'test/',target_size=(48, 48),batch_size=32,color_mode='grayscale',class_mode='categorical')
# Out:
# Found 3068 images belonging to 7 classes.

# %%
model=Sequential([
    Conv2D(32,(3, 3),activation='relu',input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),
    Conv2D(64,(3, 3),activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),
    Conv2D(128,(3,3),activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Dropout(0.25),
    Flatten(),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(7,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(train_generator,epochs=25)
# Out:
# Epoch 1/25
# 388/388 [==============================] - 96s 238ms/step - loss: 1.7891 - accuracy: 0.4100
# Epoch 2/25
# 388/388 [==============================] - 92s 236ms/step - loss: 1.1989 - accuracy: 0.5763
# Epoch 3/25
# 388/388 [==============================] - 91s 234ms/step - loss: 1.0251 - accuracy: 0.6321
# Epoch 4/25
# 388/388 [==============================] - 94s 241ms/step - loss: 0.9334 - accuracy: 0.6683
# Epoch 5/25
# 388/388 [==============================] - 92s 238ms/step - loss: 0.8845 - accuracy: 0.6846
# Epoch 6/25
# 388/388 [==============================] - 96s 248ms/step - loss: 0.8317 - accuracy: 0.7049
# Epoch 7/25
# 388/388 [==============================] - 94s 241ms/step - loss: 0.8034 - accuracy: 0.7157
# Epoch 8/25
# 388/388 [==============================] - 91s 234ms/step - loss: 0.7722 - accuracy: 0.7277
# Epoch 9/25
# 388/388 [==============================] - 94s 241ms/step - loss: 0.7395 - accuracy: 0.7386
# Epoch 10/25
# ...

# %%
test_loss,test_acc=model.evaluate(test_generator)
print('Accuracy:',test_acc)
# Out:
# 96/96 [==============================] - 15s 153ms/step - loss: 0.7116 - accuracy: 0.7500
# Accuracy: 0.75
